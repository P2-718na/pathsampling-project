# %% [markdown]
# # Restart from existing production file and continue

# %% [markdown]
# #### Restarting to generate more data

# %% [markdown]
# We obviously need OPS

# %%
import openpathsampling as paths

# %% [markdown]
# Open the storage with mode `a` for appendable.

# %%
storage = paths.Storage("ala_mstis_production.nc", "a")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 storage = paths.Storage("ala_mstis_production.nc", "a")
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/storage/storage.py:61, in Storage.__init__(self, filename, mode, template, fallback)
#      53 def __init__(
#      54         self,
#      55         filename,
#      56         mode=None,
#      57         template=None,
#      58         fallback=None):
#      60     self._template = template
# ---> 61     super(Storage, self).__init__(
#      62         filename,
#      63         mode,
#      64         fallback=fallback)
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/netcdfplus/netcdfplus.py:341, in NetCDFPlus.__init__(self, filename, mode, fallback)
#     338         store.register(self, store.name)
#     340 self.update_delegates()
# --> 341 self._restore_storages()
#     343 # only if we have a new style file
#     344 if hasattr(self, 'attributes'):
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/netcdfplus/netcdfplus.py:578, in NetCDFPlus._restore_storages(self)
#     569 """
#     570 Run the restore method on all added classes
#     571
#    (...)
#     574 Only runs when an existing storage is opened.
#     575 """
#     577 for storage in self._stores.values():
# --> 578     storage.restore()
#     579     storage._created = True
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/storage/stores/snapshot_wrapper.py:296, in SnapshotWrapperStore.restore(self)
#     295 def restore(self):
# --> 296     super(SnapshotWrapperStore, self).restore()
#     298     for idx, store in enumerate(self.storage.vars['snapshottype']):
#     299         self.type_list[store.descriptor] = (store, idx)
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/netcdfplus/stores/object.py:243, in ObjectStore.restore(self)
#     242 def restore(self):
# --> 243     self.load_indices()
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/netcdfplus/stores/object.py:247, in ObjectStore.load_indices(self)
#     245 def load_indices(self):
#     246     self.index.clear()
# --> 247     self.index.extend(self.vars['uuid'][:])
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/netcdfplus/netcdfplus.py:119, in NetCDFPlus.ValueDelegate.__getitem__(self, key)
#     116 def __getitem__(self, key):
#     117     # print(self.variable[key])
#     118     # print(type(self.variable[key]))
# --> 119     return self.getter(self.variable[key])
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/netcdfplus/netcdfplus.py:929, in NetCDFPlus.create_type_delegate.<locals>.<lambda>(v)
#     920     setter = lambda v: \
#     921         ''.join([
#     922             '-' * 36 if w is None else str(UUID(int=store.save(w)))
#     923             for w in list.__iter__(v)
#     924         ]) if set_is_iterable(v) else \
#     925         '-' * 36 if v is None else str(UUID(int=store.save(v)))
#     927 elif var_type == 'uuid':
#     928     getter = lambda v: \
# --> 929         [None if w[0] == '-' else int(UUID(w)) for w in v] \
#     930         if type(v) is not unicode else None \
#     931         if v[0] == '-' else int(UUID(v))
#     932     setter = lambda v: \
#     933         ''.join([
#     934             '-' * 36 if w is None else str(UUID(int=w))
#     935             for w in list.__iter__(v)
#     936         ]) if hasattr(v, '__iter__') else \
#     937         '-' * 36 if v is None else str(UUID(int=v))
#     939 elif var_type == 'store':
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/netcdfplus/netcdfplus.py:929, in <listcomp>(.0)
#     920     setter = lambda v: \
#     921         ''.join([
#     922             '-' * 36 if w is None else str(UUID(int=store.save(w)))
#     923             for w in list.__iter__(v)
#     924         ]) if set_is_iterable(v) else \
#     925         '-' * 36 if v is None else str(UUID(int=store.save(v)))
#     927 elif var_type == 'uuid':
#     928     getter = lambda v: \
# --> 929         [None if w[0] == '-' else int(UUID(w)) for w in v] \
#     930         if type(v) is not unicode else None \
#     931         if v[0] == '-' else int(UUID(v))
#     932     setter = lambda v: \
#     933         ''.join([
#     934             '-' * 36 if w is None else str(UUID(int=w))
#     935             for w in list.__iter__(v)
#     936         ]) if hasattr(v, '__iter__') else \
#     937         '-' * 36 if v is None else str(UUID(int=v))
#     939 elif var_type == 'store':
#
# IndexError: string index out of range

# %% [markdown]
# Next, we load the pathsimulator. Note, that this object is not really immutable and it has a state. What you actually save are all the immutable options like root sampleset and the move scheme that is used.
#
# Loading a Pathsimulator will automatically set its storage to the one you loaded from. You can of course change this manually.
#
# As a remark! The MoveScheme is also not immutable and depends on the time when you save it. This is currently
# acceptable from a useability standpoint. It should not affect you but you might keep it in mind.

# %%
mstis_calc = storage.pathsimulators[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 mstis_calc = storage.pathsimulators[0]
#
# NameError: name 'storage' is not defined

# %% [markdown]
# Since the PathSimulator is _hollow_ in the sense described above we still need to initialize it with the actual initial sampleset we want to use. If you really want to continue you can use the `restart_at_step` function and it will setup the PathSimulator in a way the it continues from the given step without creating the initial step and resetting Samples etc.

# %%
mstis_calc.restart_at_step(storage.steps[-1])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 mstis_calc.restart_at_step(storage.steps[-1])
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/netcdfplus/stores/object.py:424, in ObjectStore.__getitem__(self, item)
#     422     if item < 0:
#     423         item += len(self)
# --> 424     return self.load(item)
#     425 elif type(item) is str:
#     426     return self.load(item)
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/netcdfplus/stores/object.py:768, in ObjectStore.load(self, idx)
#     764     raise RuntimeError(
#     765         'Loading of negative int should result in no object. '
#     766         'This should never happen!')
#     767 else:
# --> 768     obj = self._load(n_idx)
#     770 if self._log_debug:
#     771     logger.debug(
#     772         'Calling load object of type %s and IDX # %d ... DONE' %
#     773         (self.content_class.__name__, n_idx))
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/netcdfplus/stores/variable.py:58, in VariableStore._load(self, idx)
#      56 def _load(self, idx):
#      57     # kwargs = {var: self.vars[var][idx] for var in self.var_names}
# ---> 58     args = [self.vars[var][idx] for var in self.var_names]
#      59     return self.content_class(*args)
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/netcdfplus/stores/variable.py:58, in <listcomp>(.0)
#      56 def _load(self, idx):
#      57     # kwargs = {var: self.vars[var][idx] for var in self.var_names}
# ---> 58     args = [self.vars[var][idx] for var in self.var_names]
#      59     return self.content_class(*args)
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/netcdfplus/netcdfplus.py:119, in NetCDFPlus.ValueDelegate.__getitem__(self, key)
#     116 def __getitem__(self, key):
#     117     # print(self.variable[key])
#     118     # print(type(self.variable[key]))
# --> 119     return self.getter(self.variable[key])
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/netcdfplus/netcdfplus.py:905, in NetCDFPlus.create_type_delegate.<locals>.<lambda>(v)
#     898     getter = lambda v: self.simplifier.from_json(v)
#     900 elif var_type.startswith('obj.'):
#     901     getter = lambda v: [
#     902         None if w[0] == '-' else store.load(int(UUID(w)))
#     903         for w in v
#     904     ] if get_numpy_iterable(v) else \
# --> 905         None if v[0] == '-' else store.load(int(UUID(v)))
#     907     setter = lambda v: \
#     908         ''.join(['-' * 36 if w is None else str(UUID(int=store.save(w)))
#     909                  for w in list.__iter__(v)]) \
#     910         if set_is_iterable(v) else \
#     911         '-' * 36 if v is None else str(UUID(int=store.save(v)))
#     913 elif var_type.startswith('lazyobj.'):
#
# IndexError: string index out of range

# %% [markdown]
# After that we are good to continue at the last (or any other) step of the simulation. This restarting will keep references to the original PathSimulation object so you can better find step that are generated from the same PathSimulator object.

# %%
mstis_calc.run(700)
# Out:
# Working on Monte Carlo cycle number 345
# Running for 29 seconds -  7.42 seconds per step
# Estimated time remaining: 1 hour 26.03 minutes
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/netcdfplus/netcdfplus.py:540, in NetCDFPlus.__getattr__(self, item)
#     539 try:
# --> 540     return self.__dict__[item]
#     541 except KeyError:
#
# KeyError: 'stash'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/netcdfplus/netcdfplus.py:543, in NetCDFPlus.__getattr__(self, item)
#     542 try:
# --> 543     return self.__class__.__dict__[item]
#     544 except KeyError:
#
# KeyError: 'stash'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/beta/hooks.py:124, in StorageHook.after_step(self, sim, step_number, step_info, state, results, hook_state)
#     123 try:
# --> 124     self.storage.stash(results)
#     125 except AttributeError:
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/netcdfplus/netcdfplus.py:545, in NetCDFPlus.__getattr__(self, item)
#     544 except KeyError:
# --> 545     raise AttributeError(
#     546         "'{cls}' object has no attribute '{itm}'".format(
#     547             cls=self.__class__, itm=item
#     548         )
#     549     )
#
# AttributeError: '<class 'openpathsampling.storage.storage.Storage'>' object has no attribute 'stash'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 mstis_calc.run(700)
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/pathsimulators/path_sampling.py:261, in PathSampling.run(self, n_steps)
#     259 for nn in range(n_steps):
#     260     step_info = nn, n_steps
# --> 261     hook_state, mcstep = self.run_one_step(step_info, hook_state)
#     263 # after simulation hooks
#     264 self.run_hooks('after_simulation', sim=self, hook_state=hook_state)
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/pathsimulators/path_sampling.py:310, in PathSampling.run_one_step(self, step_info, hook_state)
#     307 self.sample_set = new_sampleset
#     309 # run after_step hooks
# --> 310 hook_state = self.run_hooks('after_step', sim=self,
#     311                             step_number=step_number,
#     312                             step_info=step_info,
#     313                             state=self.sample_set,
#     314                             results=mcstep,
#     315                             hook_state=hook_state
#     316                             )
#     317 return hook_state, mcstep
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/pathsimulators/path_simulator.py:135, in PathSimulator.run_hooks(self, hook_name, **kwargs)
#     133 hook_name_state = {}
#     134 for hook in self.hooks[hook_name]:
# --> 135     result = hook(**kwargs)
#     136     if result is not None:
#     137         hook_name_state[hook] = result
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/beta/hooks.py:126, in StorageHook.after_step(self, sim, step_number, step_info, state, results, hook_state)
#     124     self.storage.stash(results)
#     125 except AttributeError:
# --> 126     self.storage.save(results)
#     127 if step_number % self.frequency == 0:
#     128     self.storage.sync_all()
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/netcdfplus/netcdfplus.py:637, in NetCDFPlus.save(self, obj, idx)
#     635     store = self.find_store(obj)
#     636     store_idx = self.stores.index[store.__uuid__]
# --> 637     return store, store_idx, store.save(obj, idx)
#     639 # Could not save this object.
#     640 raise RuntimeWarning("Objects of type '%s' cannot be stored!" %
#     641                      obj.__class__.__name__)
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/netcdfplus/stores/object.py:894, in ObjectStore.save(self, obj, idx)
#     891 logger.debug('Saving ' + str(type(obj)) + ' using IDX #' + str(n_idx))
#     893 try:
# --> 894     self._save(obj, n_idx)
#     895     self._auto_complete(obj, n_idx)
#     896     self.cache[n_idx] = obj
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/netcdfplus/stores/variable.py:54, in VariableStore._save(self, obj, idx)
#      52 def _save(self, obj, idx):
#      53     for var in self.var_names:
# ---> 54         self.write(var, idx, obj)
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/netcdfplus/stores/object.py:359, in ObjectStore.write(self, variable, idx, obj, attribute)
#     356 var = self.vars[variable]
#     357 val = getattr(obj, attribute)
# --> 359 var[int(idx)] = val
#     361 if var.var_type.startswith('lazy'):
#     362     proxy = var.store.proxy(val)
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/netcdfplus/netcdfplus.py:114, in NetCDFPlus.ValueDelegate.__setitem__(self, key, value)
#     113 def __setitem__(self, key, value):
# --> 114     self.variable[key] = self.setter(value)
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/netcdfplus/netcdfplus.py:911, in NetCDFPlus.create_type_delegate.<locals>.<lambda>(v)
#     900 elif var_type.startswith('obj.'):
#     901     getter = lambda v: [
#     902         None if w[0] == '-' else store.load(int(UUID(w)))
#     903         for w in v
#     904     ] if get_numpy_iterable(v) else \
#     905         None if v[0] == '-' else store.load(int(UUID(v)))
#     907     setter = lambda v: \
#     908         ''.join(['-' * 36 if w is None else str(UUID(int=store.save(w)))
#     909                  for w in list.__iter__(v)]) \
#     910         if set_is_iterable(v) else \
# --> 911         '-' * 36 if v is None else str(UUID(int=store.save(v)))
#     913 elif var_type.startswith('lazyobj.'):
#     914     getter = lambda v: [
#     915         None if w[0] == '-' else LoaderProxy.new(store, int(UUID(w)))
#     916         for w in v
#     917     ] if isinstance(v, np.ndarray) else \
#     918         None if v[0] == '-' else LoaderProxy.new(store, int(UUID(v)))
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/netcdfplus/stores/object.py:894, in ObjectStore.save(self, obj, idx)
#     891 logger.debug('Saving ' + str(type(obj)) + ' using IDX #' + str(n_idx))
#     893 try:
# --> 894     self._save(obj, n_idx)
#     895     self._auto_complete(obj, n_idx)
#     896     self.cache[n_idx] = obj
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/storage/stores/movechange.py:23, in MoveChangeStore._save(self, movechange, idx)
#      21 self.vars['samples'][idx] = movechange.samples
#      22 self.vars['input_samples'][idx] = movechange.input_samples
# ---> 23 self.vars['subchanges'][idx] = movechange.subchanges
#      24 self.write('details', idx, movechange)
#      25 self.vars['mover'][idx] = movechange.mover
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/netcdfplus/netcdfplus.py:114, in NetCDFPlus.ValueDelegate.__setitem__(self, key, value)
#     113 def __setitem__(self, key, value):
# --> 114     self.variable[key] = self.setter(value)
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/netcdfplus/netcdfplus.py:908, in NetCDFPlus.create_type_delegate.<locals>.<lambda>(v)
#     900 elif var_type.startswith('obj.'):
#     901     getter = lambda v: [
#     902         None if w[0] == '-' else store.load(int(UUID(w)))
#     903         for w in v
#     904     ] if get_numpy_iterable(v) else \
#     905         None if v[0] == '-' else store.load(int(UUID(v)))
#     907     setter = lambda v: \
# --> 908         ''.join(['-' * 36 if w is None else str(UUID(int=store.save(w)))
#     909                  for w in list.__iter__(v)]) \
#     910         if set_is_iterable(v) else \
#     911         '-' * 36 if v is None else str(UUID(int=store.save(v)))
#     913 elif var_type.startswith('lazyobj.'):
#     914     getter = lambda v: [
#     915         None if w[0] == '-' else LoaderProxy.new(store, int(UUID(w)))
#     916         for w in v
#     917     ] if isinstance(v, np.ndarray) else \
#     918         None if v[0] == '-' else LoaderProxy.new(store, int(UUID(v)))
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/netcdfplus/netcdfplus.py:908, in <listcomp>(.0)
#     900 elif var_type.startswith('obj.'):
#     901     getter = lambda v: [
#     902         None if w[0] == '-' else store.load(int(UUID(w)))
#     903         for w in v
#     904     ] if get_numpy_iterable(v) else \
#     905         None if v[0] == '-' else store.load(int(UUID(v)))
#     907     setter = lambda v: \
# --> 908         ''.join(['-' * 36 if w is None else str(UUID(int=store.save(w)))
#     909                  for w in list.__iter__(v)]) \
#     910         if set_is_iterable(v) else \
#     911         '-' * 36 if v is None else str(UUID(int=store.save(v)))
#     913 elif var_type.startswith('lazyobj.'):
#     914     getter = lambda v: [
#     915         None if w[0] == '-' else LoaderProxy.new(store, int(UUID(w)))
#     916         for w in v
#     917     ] if isinstance(v, np.ndarray) else \
#     918         None if v[0] == '-' else LoaderProxy.new(store, int(UUID(v)))
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/netcdfplus/stores/object.py:894, in ObjectStore.save(self, obj, idx)
#     891 logger.debug('Saving ' + str(type(obj)) + ' using IDX #' + str(n_idx))
#     893 try:
# --> 894     self._save(obj, n_idx)
#     895     self._auto_complete(obj, n_idx)
#     896     self.cache[n_idx] = obj
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/storage/stores/movechange.py:23, in MoveChangeStore._save(self, movechange, idx)
#      21 self.vars['samples'][idx] = movechange.samples
#      22 self.vars['input_samples'][idx] = movechange.input_samples
# ---> 23 self.vars['subchanges'][idx] = movechange.subchanges
#      24 self.write('details', idx, movechange)
#      25 self.vars['mover'][idx] = movechange.mover
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/netcdfplus/netcdfplus.py:114, in NetCDFPlus.ValueDelegate.__setitem__(self, key, value)
#     113 def __setitem__(self, key, value):
# --> 114     self.variable[key] = self.setter(value)
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/netcdfplus/netcdfplus.py:908, in NetCDFPlus.create_type_delegate.<locals>.<lambda>(v)
#     900 elif var_type.startswith('obj.'):
#     901     getter = lambda v: [
#     902         None if w[0] == '-' else store.load(int(UUID(w)))
#     903         for w in v
#     904     ] if get_numpy_iterable(v) else \
#     905         None if v[0] == '-' else store.load(int(UUID(v)))
#     907     setter = lambda v: \
# --> 908         ''.join(['-' * 36 if w is None else str(UUID(int=store.save(w)))
#     909                  for w in list.__iter__(v)]) \
#     910         if set_is_iterable(v) else \
#     911         '-' * 36 if v is None else str(UUID(int=store.save(v)))
#     913 elif var_type.startswith('lazyobj.'):
#     914     getter = lambda v: [
#     915         None if w[0] == '-' else LoaderProxy.new(store, int(UUID(w)))
#     916         for w in v
#     917     ] if isinstance(v, np.ndarray) else \
#     918         None if v[0] == '-' else LoaderProxy.new(store, int(UUID(v)))
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/netcdfplus/netcdfplus.py:908, in <listcomp>(.0)
#     900 elif var_type.startswith('obj.'):
#     901     getter = lambda v: [
#     902         None if w[0] == '-' else store.load(int(UUID(w)))
#     903         for w in v
#     904     ] if get_numpy_iterable(v) else \
#     905         None if v[0] == '-' else store.load(int(UUID(v)))
#     907     setter = lambda v: \
# --> 908         ''.join(['-' * 36 if w is None else str(UUID(int=store.save(w)))
#     909                  for w in list.__iter__(v)]) \
#     910         if set_is_iterable(v) else \
#     911         '-' * 36 if v is None else str(UUID(int=store.save(v)))
#     913 elif var_type.startswith('lazyobj.'):
#     914     getter = lambda v: [
#     915         None if w[0] == '-' else LoaderProxy.new(store, int(UUID(w)))
#     916         for w in v
#     917     ] if isinstance(v, np.ndarray) else \
#     918         None if v[0] == '-' else LoaderProxy.new(store, int(UUID(v)))
#
#     [... skipping similar frames: ObjectStore.save at line 894 (2 times), NetCDFPlus.create_type_delegate.<locals>.<lambda> at line 908 (1 times), <listcomp> at line 908 (1 times), NetCDFPlus.ValueDelegate.__setitem__ at line 114 (1 times), MoveChangeStore._save at line 23 (1 times)]
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/storage/stores/movechange.py:23, in MoveChangeStore._save(self, movechange, idx)
#      21 self.vars['samples'][idx] = movechange.samples
#      22 self.vars['input_samples'][idx] = movechange.input_samples
# ---> 23 self.vars['subchanges'][idx] = movechange.subchanges
#      24 self.write('details', idx, movechange)
#      25 self.vars['mover'][idx] = movechange.mover
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/netcdfplus/netcdfplus.py:114, in NetCDFPlus.ValueDelegate.__setitem__(self, key, value)
#     113 def __setitem__(self, key, value):
# --> 114     self.variable[key] = self.setter(value)
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/netcdfplus/netcdfplus.py:908, in NetCDFPlus.create_type_delegate.<locals>.<lambda>(v)
#     900 elif var_type.startswith('obj.'):
#     901     getter = lambda v: [
#     902         None if w[0] == '-' else store.load(int(UUID(w)))
#     903         for w in v
#     904     ] if get_numpy_iterable(v) else \
#     905         None if v[0] == '-' else store.load(int(UUID(v)))
#     907     setter = lambda v: \
# --> 908         ''.join(['-' * 36 if w is None else str(UUID(int=store.save(w)))
#     909                  for w in list.__iter__(v)]) \
#     910         if set_is_iterable(v) else \
#     911         '-' * 36 if v is None else str(UUID(int=store.save(v)))
#     913 elif var_type.startswith('lazyobj.'):
#     914     getter = lambda v: [
#     915         None if w[0] == '-' else LoaderProxy.new(store, int(UUID(w)))
#     916         for w in v
#     917     ] if isinstance(v, np.ndarray) else \
#     918         None if v[0] == '-' else LoaderProxy.new(store, int(UUID(v)))
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/netcdfplus/netcdfplus.py:908, in <listcomp>(.0)
#     900 elif var_type.startswith('obj.'):
#     901     getter = lambda v: [
#     902         None if w[0] == '-' else store.load(int(UUID(w)))
#     903         for w in v
#     904     ] if get_numpy_iterable(v) else \
#     905         None if v[0] == '-' else store.load(int(UUID(v)))
#     907     setter = lambda v: \
# --> 908         ''.join(['-' * 36 if w is None else str(UUID(int=store.save(w)))
#     909                  for w in list.__iter__(v)]) \
#     910         if set_is_iterable(v) else \
#     911         '-' * 36 if v is None else str(UUID(int=store.save(v)))
#     913 elif var_type.startswith('lazyobj.'):
#     914     getter = lambda v: [
#     915         None if w[0] == '-' else LoaderProxy.new(store, int(UUID(w)))
#     916         for w in v
#     917     ] if isinstance(v, np.ndarray) else \
#     918         None if v[0] == '-' else LoaderProxy.new(store, int(UUID(v)))
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/netcdfplus/stores/object.py:894, in ObjectStore.save(self, obj, idx)
#     891 logger.debug('Saving ' + str(type(obj)) + ' using IDX #' + str(n_idx))
#     893 try:
# --> 894     self._save(obj, n_idx)
#     895     self._auto_complete(obj, n_idx)
#     896     self.cache[n_idx] = obj
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/storage/stores/movechange.py:21, in MoveChangeStore._save(self, movechange, idx)
#      20 def _save(self, movechange, idx):
# ---> 21     self.vars['samples'][idx] = movechange.samples
#      22     self.vars['input_samples'][idx] = movechange.input_samples
#      23     self.vars['subchanges'][idx] = movechange.subchanges
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/netcdfplus/netcdfplus.py:114, in NetCDFPlus.ValueDelegate.__setitem__(self, key, value)
#     113 def __setitem__(self, key, value):
# --> 114     self.variable[key] = self.setter(value)
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/netcdfplus/netcdfplus.py:908, in NetCDFPlus.create_type_delegate.<locals>.<lambda>(v)
#     900 elif var_type.startswith('obj.'):
#     901     getter = lambda v: [
#     902         None if w[0] == '-' else store.load(int(UUID(w)))
#     903         for w in v
#     904     ] if get_numpy_iterable(v) else \
#     905         None if v[0] == '-' else store.load(int(UUID(v)))
#     907     setter = lambda v: \
# --> 908         ''.join(['-' * 36 if w is None else str(UUID(int=store.save(w)))
#     909                  for w in list.__iter__(v)]) \
#     910         if set_is_iterable(v) else \
#     911         '-' * 36 if v is None else str(UUID(int=store.save(v)))
#     913 elif var_type.startswith('lazyobj.'):
#     914     getter = lambda v: [
#     915         None if w[0] == '-' else LoaderProxy.new(store, int(UUID(w)))
#     916         for w in v
#     917     ] if isinstance(v, np.ndarray) else \
#     918         None if v[0] == '-' else LoaderProxy.new(store, int(UUID(v)))
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/netcdfplus/netcdfplus.py:908, in <listcomp>(.0)
#     900 elif var_type.startswith('obj.'):
#     901     getter = lambda v: [
#     902         None if w[0] == '-' else store.load(int(UUID(w)))
#     903         for w in v
#     904     ] if get_numpy_iterable(v) else \
#     905         None if v[0] == '-' else store.load(int(UUID(v)))
#     907     setter = lambda v: \
# --> 908         ''.join(['-' * 36 if w is None else str(UUID(int=store.save(w)))
#     909                  for w in list.__iter__(v)]) \
#     910         if set_is_iterable(v) else \
#     911         '-' * 36 if v is None else str(UUID(int=store.save(v)))
#     913 elif var_type.startswith('lazyobj.'):
#     914     getter = lambda v: [
#     915         None if w[0] == '-' else LoaderProxy.new(store, int(UUID(w)))
#     916         for w in v
#     917     ] if isinstance(v, np.ndarray) else \
#     918         None if v[0] == '-' else LoaderProxy.new(store, int(UUID(v)))
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/netcdfplus/stores/object.py:894, in ObjectStore.save(self, obj, idx)
#     891 logger.debug('Saving ' + str(type(obj)) + ' using IDX #' + str(n_idx))
#     893 try:
# --> 894     self._save(obj, n_idx)
#     895     self._auto_complete(obj, n_idx)
#     896     self.cache[n_idx] = obj
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/netcdfplus/stores/variable.py:54, in VariableStore._save(self, obj, idx)
#      52 def _save(self, obj, idx):
#      53     for var in self.var_names:
# ---> 54         self.write(var, idx, obj)
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/netcdfplus/stores/object.py:359, in ObjectStore.write(self, variable, idx, obj, attribute)
#     356 var = self.vars[variable]
#     357 val = getattr(obj, attribute)
# --> 359 var[int(idx)] = val
#     361 if var.var_type.startswith('lazy'):
#     362     proxy = var.store.proxy(val)
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/netcdfplus/netcdfplus.py:114, in NetCDFPlus.ValueDelegate.__setitem__(self, key, value)
#     113 def __setitem__(self, key, value):
# --> 114     self.variable[key] = self.setter(value)
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/netcdfplus/netcdfplus.py:911, in NetCDFPlus.create_type_delegate.<locals>.<lambda>(v)
#     900 elif var_type.startswith('obj.'):
#     901     getter = lambda v: [
#     902         None if w[0] == '-' else store.load(int(UUID(w)))
#     903         for w in v
#     904     ] if get_numpy_iterable(v) else \
#     905         None if v[0] == '-' else store.load(int(UUID(v)))
#     907     setter = lambda v: \
#     908         ''.join(['-' * 36 if w is None else str(UUID(int=store.save(w)))
#     909                  for w in list.__iter__(v)]) \
#     910         if set_is_iterable(v) else \
# --> 911         '-' * 36 if v is None else str(UUID(int=store.save(v)))
#     913 elif var_type.startswith('lazyobj.'):
#     914     getter = lambda v: [
#     915         None if w[0] == '-' else LoaderProxy.new(store, int(UUID(w)))
#     916         for w in v
#     917     ] if isinstance(v, np.ndarray) else \
#     918         None if v[0] == '-' else LoaderProxy.new(store, int(UUID(v)))
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/netcdfplus/stores/object.py:895, in ObjectStore.save(self, obj, idx)
#     893 try:
#     894     self._save(obj, n_idx)
# --> 895     self._auto_complete(obj, n_idx)
#     896     self.cache[n_idx] = obj
#     898 except:
#     899     # in case we did not succeed remove the mark as being saved
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/netcdfplus/stores/object.py:979, in ObjectStore._auto_complete(self, obj, pos)
#     971 for attribute, attribute_store in self.attribute_list.items():
#     972     if not attribute_store.allow_incomplete:
#     973         # value = attribute._cache_dict._get(obj)
#     974         # if value is None:
#     975         #     # not in cache so compute it if possible
#     976         #     if attribute._eval_dict:
#     977         #         value = attribute._eval_dict([obj])[0]
# --> 979         value = attribute(obj)
#     981         if value is not None:
#     982             if attribute_store.allow_incomplete:
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/netcdfplus/chaindict.py:229, in Wrap.__getitem__(self, items)
#     228 def __getitem__(self, items):
# --> 229     return self._post[items]
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/netcdfplus/chaindict.py:260, in ExpandSingle.__getitem__(self, items)
#     258 def __getitem__(self, items):
#     259     if isinstance(items, self.key_class):
# --> 260         return self._post[[items]][0]
#     261     # elif type(items) is LoaderProxy:
#     262     #     return self._post[[items]][0]
#     263     elif hasattr(items.__class__, '__iter__'):
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/netcdfplus/chaindict.py:74, in ChainDict.__getitem__(self, items)
#      72     return results
#      73 else:
# ---> 74     rep = list(self._post[nones])
#      75     self._set_list(nones, rep)
#      77     it = iter(rep)
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/netcdfplus/chaindict.py:74, in ChainDict.__getitem__(self, items)
#      72     return results
#      73 else:
# ---> 74     rep = list(self._post[nones])
#      75     self._set_list(nones, rep)
#      77     it = iter(rep)
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/netcdfplus/chaindict.py:67, in ChainDict.__getitem__(self, items)
#      63 def __getitem__(self, items):
#      64     # first apply the own _get functions to compute
#      65     # print 'get %d items using %s' % (len(items), self.__class__.__name__)
# ---> 67     results = self._get_list(items)
#      69     if self._post is not None:
#      70         nones = [obj[0] for obj in zip(items, results) if obj[1] is None]
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/netcdfplus/chaindict.py:365, in Function._get_list(self, items)
#     362         results = results.reshape(results.shape[:-1])
#     364 else:
# --> 365     results = [self._eval(obj) for obj in items]
#     366     if self.scalarize_numpy_singletons and results[0].shape[-1] == 1:
#     367         results = map(lambda x: x.reshape(x.shape[:-1]), results)
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/netcdfplus/chaindict.py:365, in <listcomp>(.0)
#     362         results = results.reshape(results.shape[:-1])
#     364 else:
# --> 365     results = [self._eval(obj) for obj in items]
#     366     if self.scalarize_numpy_singletons and results[0].shape[-1] == 1:
#     367         results = map(lambda x: x.reshape(x.shape[:-1]), results)
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/netcdfplus/attribute.py:404, in FunctionPseudoAttribute._eval(self, items)
#     402 def _eval(self, items):
#     403     # here the kwargs are used in the callable when it is evaluated
# --> 404     return self.cv_callable(items, **self.kwargs)
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/high_level/interface_set.py:9, in _cv_max_func(trajectory, cv)
#       8 def _cv_max_func(trajectory, cv):
# ----> 9     return max(cv(trajectory))
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/netcdfplus/chaindict.py:229, in Wrap.__getitem__(self, items)
#     228 def __getitem__(self, items):
# --> 229     return self._post[items]
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/netcdfplus/chaindict.py:273, in ExpandSingle.__getitem__(self, items)
#     268     raise AttributeError(
#     269         'Iterators that do not have __len__ implemented are not '
#     270         'supported. You can wrap your iterator in list() if you '
#     271         'know that it will finish.')
#     272 try:
# --> 273     return self._post[items.as_proxies()]
#     274 except AttributeError:
#     275     # turn possible iterators into a list if possible
#     276     return self._post[list(items)]
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/netcdfplus/chaindict.py:74, in ChainDict.__getitem__(self, items)
#      72     return results
#      73 else:
# ---> 74     rep = list(self._post[nones])
#      75     self._set_list(nones, rep)
#      77     it = iter(rep)
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/netcdfplus/chaindict.py:67, in ChainDict.__getitem__(self, items)
#      63 def __getitem__(self, items):
#      64     # first apply the own _get functions to compute
#      65     # print 'get %d items using %s' % (len(items), self.__class__.__name__)
# ---> 67     results = self._get_list(items)
#      69     if self._post is not None:
#      70         nones = [obj[0] for obj in zip(items, results) if obj[1] is None]
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/netcdfplus/chaindict.py:365, in Function._get_list(self, items)
#     362         results = results.reshape(results.shape[:-1])
#     364 else:
# --> 365     results = [self._eval(obj) for obj in items]
#     366     if self.scalarize_numpy_singletons and results[0].shape[-1] == 1:
#     367         results = map(lambda x: x.reshape(x.shape[:-1]), results)
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/netcdfplus/chaindict.py:365, in <listcomp>(.0)
#     362         results = results.reshape(results.shape[:-1])
#     364 else:
# --> 365     results = [self._eval(obj) for obj in items]
#     366     if self.scalarize_numpy_singletons and results[0].shape[-1] == 1:
#     367         results = map(lambda x: x.reshape(x.shape[:-1]), results)
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/collectivevariable.py:342, in FunctionCV._eval(self, items)
#     340 def _eval(self, items):
#     341     # here the kwargs are used in the callable when it is evaluated
# --> 342     return self.cv_callable(items, **self.kwargs)
#
# File /var/folders/1d/kcghq1vj1vsdrvzqy0y2yhz00000gn/T/ipykernel_35240/522872638.py:3, in circle_degree(snapshot, center, phi, psi)
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/netcdfplus/chaindict.py:229, in Wrap.__getitem__(self, items)
#     228 def __getitem__(self, items):
# --> 229     return self._post[items]
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/netcdfplus/chaindict.py:242, in MergeNumpy.__getitem__(self, items)
#     241 def __getitem__(self, items):
# --> 242     return np.array(self._post[items])
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/netcdfplus/chaindict.py:260, in ExpandSingle.__getitem__(self, items)
#     258 def __getitem__(self, items):
#     259     if isinstance(items, self.key_class):
# --> 260         return self._post[[items]][0]
#     261     # elif type(items) is LoaderProxy:
#     262     #     return self._post[[items]][0]
#     263     elif hasattr(items.__class__, '__iter__'):
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/netcdfplus/chaindict.py:74, in ChainDict.__getitem__(self, items)
#      72     return results
#      73 else:
# ---> 74     rep = list(self._post[nones])
#      75     self._set_list(nones, rep)
#      77     it = iter(rep)
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/netcdfplus/chaindict.py:74, in ChainDict.__getitem__(self, items)
#      72     return results
#      73 else:
# ---> 74     rep = list(self._post[nones])
#      75     self._set_list(nones, rep)
#      77     it = iter(rep)
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/netcdfplus/chaindict.py:67, in ChainDict.__getitem__(self, items)
#      63 def __getitem__(self, items):
#      64     # first apply the own _get functions to compute
#      65     # print 'get %d items using %s' % (len(items), self.__class__.__name__)
# ---> 67     results = self._get_list(items)
#      69     if self._post is not None:
#      70         nones = [obj[0] for obj in zip(items, results) if obj[1] is None]
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/netcdfplus/chaindict.py:359, in Function._get_list(self, items)
#     356     return [None] * len(items)
#     358 if self.requires_lists:
# --> 359     results = self._eval(items)
#     361     if self.scalarize_numpy_singletons and results.shape[-1] == 1:
#     362         results = results.reshape(results.shape[:-1])
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/collectivevariable.py:570, in MDTrajFunctionCV._eval(self, items)
#     567 def _eval(self, items):
#     568     trajectory = paths.Trajectory(items)
# --> 570     t = trajectory_to_mdtraj(trajectory, self.topology.mdtraj)
#     571     return self.cv_callable(t, **self.kwargs)
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/engines/openmm/tools.py:373, in trajectory_to_mdtraj(trajectory, md_topology)
#     369         trajectory = Trajectory(trajectory)
#     371 # For now, let's keep all the code in one place, and better for
#     372 # engines.openmm.tools to require engines.trajectory than vice versa
# --> 373 return trajectory.to_mdtraj(md_topology)
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/engines/trajectory.py:548, in Trajectory.to_mdtraj(self, topology)
#     543 if topology is None:
#     544     # TODO: maybe add better error output?
#     545     # if AttributeError here, engine doesn't support mdtraj
#     546     topology = snap.engine.mdtraj_topology
# --> 548 output = self.xyz
#     550 traj = md.Trajectory(output, topology)
#     551 box_vectors = self.box_vectors
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/engines/trajectory.py:151, in Trajectory.__getattr__(self, item)
#     148     return traj_func(self)
#     150 # get the results
# --> 151 out = [getattr(snap, item) for snap in self]
#     153 # if the first result is a numpy object, return the whole as a
#     154 # numpy array
#     155 if isinstance(out[0], np.ndarray):
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/engines/trajectory.py:151, in <listcomp>(.0)
#     148     return traj_func(self)
#     150 # get the results
# --> 151 out = [getattr(snap, item) for snap in self]
#     153 # if the first result is a numpy object, return the whole as a
#     154 # numpy array
#     155 if isinstance(out[0], np.ndarray):
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/engines/features/statics.py:130, in xyz(snapshot)
#     121 """
#     122 Returns
#     123 -------
#    (...)
#     126
#     127 """
#     128 from openpathsampling.integration_tools import unit as u
# --> 130 coord = snapshot.coordinates
#     131 if type(coord) is u.Quantity:
#     132     return coord._value
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/engines/features/statics.py:58, in coordinates(snapshot)
#      49 """
#      50 Returns
#      51 -------
#    (...)
#      54     wrapped in a :class:`openmm.unit.Unit`.
#      55 """
#      57 if snapshot.statics is not None:
# ---> 58     return unmask_quantity(snapshot.statics.coordinates)
#      60 return None
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/netcdfplus/proxy.py:89, in LoaderProxy.__getattr__(self, item)
#      88 def __getattr__(self, item):
# ---> 89     return getattr(self.__subject__, item)
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/netcdfplus/proxy.py:47, in LoaderProxy.__subject__(self)
#      44     if obj is not None:
#      45         return obj
# ---> 47 ref = self._load_()
#      49 if ref is None:
#      50     return None
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/netcdfplus/proxy.py:96, in LoaderProxy._load_(self)
#      92 """
#      93 Call the loader and get the referenced object
#      94 """
#      95 try:
# ---> 96     return self._store.load(self.__uuid__)
#      97 except KeyError:
#      98     if type(self.__uuid__) is int:
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/netcdfplus/stores/object.py:768, in ObjectStore.load(self, idx)
#     764     raise RuntimeError(
#     765         'Loading of negative int should result in no object. '
#     766         'This should never happen!')
#     767 else:
# --> 768     obj = self._load(n_idx)
#     770 if self._log_debug:
#     771     logger.debug(
#     772         'Calling load object of type %s and IDX # %d ... DONE' %
#     773         (self.content_class.__name__, n_idx))
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/engines/features/shared.py:116, in StaticContainerStore._load(self, idx)
#     114 def _load(self, idx):
#     115     coordinates = self.vars["coordinates"][idx]
# --> 116     box_vectors = self.vars["box_vectors"][idx]
#     118     if not np.count_nonzero(box_vectors):
#     119         box_vectors = None
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/netcdfplus/netcdfplus.py:119, in NetCDFPlus.ValueDelegate.__getitem__(self, key)
#     116 def __getitem__(self, key):
#     117     # print(self.variable[key])
#     118     # print(type(self.variable[key]))
# --> 119     return self.getter(self.variable[key])
#
# File ~/.local/share/virtualenvs/quantum-folding-aHaLeqp8/lib/python3.11/site-packages/openpathsampling/netcdfplus/netcdfplus.py:1001, in NetCDFPlus.create_variable_delegate.<locals>._get.<locals>.<lambda>(v)
#     999 def _get(my_getter):
#    1000     if my_getter is None:
# -> 1001         return lambda v: u.Quantity(v, unit)
#    1002     else:
#    1003         return lambda v: u.Quantity(my_getter(v), unit)
#
# KeyboardInterrupt:

# %% [markdown]
# Check the current file size

# %%
storage.file_size_str
# Out:
# '383.28MB'

# %% [markdown]
# And close the file. We can continue later...

# %%
storage.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 storage.close()
#
# NameError: name 'storage' is not defined
